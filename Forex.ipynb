# %%
import pandas as pd
import numpy as np

# %%
file_path = '../CapStone/ForeignEx/data/'
file_path_us = file_path + 'US'
file_path_eu = file_path + 'EU'
df_us_cpi = pd.read_csv('../CapStone/ForeignEx/data/US/US_CPI_SeriesReport_monthly_2019_1947.csv')
df_us_gpd = pd.read_csv('../CapStone/ForeignEx/data/US/US_GDP_Q_US.csv')
df_us_ir = pd.read_csv('../CapStone/ForeignEx/data/US/US_Month_Treasury_Constant_Maturity_Rate.csv')
df_us_ie = pd.read_csv('../CapStone/ForeignEx/data/US/usa_iexport.tsv', sep='\t', header=None)

# %%
df_us_ie_2k5 = df_us_ie[ df_us_ie[0] >= 2005]

# %%
df_us_ie_2k5.head()
df_us_jpn_ie = df_us_ie[(df_us_ie[1] == 'jpn') | (df_us_ie[2] == 'jpn')]
# df_us_jpn_ie.head()

# %%
df_us_jpn_ie[4] = df_us_jpn_ie[4].fillna(value=0)
df_us_jpn_ie.head()
df_us_jpn_ie[5] = df_us_jpn_ie[5].fillna(value=0)
df_us_jpn_ie.head()
# Out:
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           0    1    2      3           4            5
# 51079  1998  jpn  usa  10111   584310.00  23397947.55
# 51080  1998  jpn  usa  10119  2064390.17   3281269.00
# 51081  1998  jpn  usa  10210   436842.08   2565999.03
# 51082  1998  jpn  usa  10290   632268.00      8938.67
# 51083  1998  jpn  usa  10310        0.00    351447.43

# %%
gby = df_us_jpn_ie.groupby([0,1,2]).sum().reset_index()

# %%
df_us_jpn_his = gby[::2].reset_index()

# %%
df_us_jpn_his
# Out:
#     index     0    1    2           3             4             5
# 0       0  1998  jpn  usa  2574562606  1.134330e+11  5.632403e+10
# 1       2  1999  jpn  usa  2570832676  1.214687e+11  5.577455e+10
# 2       4  2000  jpn  usa  2684609109  1.429120e+11  6.540910e+10
# 3       6  2001  jpn  usa  2658169920  1.227793e+11  5.685211e+10
# 4       8  2002  jpn  usa  2613240762  1.188748e+11  5.166082e+10
# 5      10  2003  jpn  usa  2602792885  1.137569e+11  5.277195e+10
# 6      12  2004  jpn  usa  2610369085  1.256610e+11  5.616202e+10
# 7      14  2005  jpn  usa  2636159605  1.338761e+11  5.814089e+10
# 8      16  2006  jpn  usa  2629135678  1.439221e+11  6.207442e+10
# 9      18  2007  jpn  usa  2469834893  1.404683e+11  6.349752e+10
# 10     20  2008  jpn  usa  2473324768  1.376014e+11  7.133262e+10
# 11     22  2009  jpn  usa  2456027200  9.379302e+10  5.445651e+10
# 12     24  2010  jpn  usa  2458441682  1.177821e+11  6.301895e+10
# 13     26  2011  jpn  usa  2457676016  1.259511e+11  6.945123e+10
# 14     28  2014  usa  jpn  2442181312  6.753808e+10  1.319245e+11
# 15     30  2015  usa  jpn  2454401460  6.328616e+10  1.283831e+11
# 16     32  2016  usa  jpn  2449792327  6.529587e+10  1.295955e+11
# 17     34  2017  usa  jpn  2386166739  6.856065e+10  1.250441e+11

# %%
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir.info()
df_us_ir.head()
ser = df_us_ir.set_index('year')['VALUE']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4553 entries, 0 to 4552
# Data columns (total 3 columns):
# DATE     4553 non-null object
# VALUE    4553 non-null object
# year     4553 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 106.8+ KB

# %%
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))

# %%
# df_us_ir['VALUE'].apply(lambda x:float(x))
# df_us_ir.VALUE = df_us_ir.VALUE.astype(float)
# df_us_ir.VALUE.describe()
# df_us_ir['VALUE'] = df_us_ir['VALUE'].astype(float)
# df_us_ir = pd.read_csv('../CapStone/ForeignEx/data/US/US_Month_Treasury_Constant_Maturity_Rate.csv')

df_us_ir = df_us_ir[~(df_us_ir['VALUE'] == '.')]
df_us_ir['VALUE'] = df_us_ir['VALUE'].astype(float)

df_us_ir.groupby('DATE').mean()
df_us_ir['YEAR']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir_his = df_us_ir.groupby('YEAR').mean()

# %%
df_us_cpi = pd.read_csv('../CapStone/ForeignEx/data/US/US_CPI_SeriesReport_monthly_2019_1947.csv')

df_us_cpi = df_us_cpi[10:].reset_index()

# %%
df_us_cpi.columns = df_us_cpi.iloc[0]
df_us_cpi = df_us_cpi.drop(0).reset_index()

# %%
# df_us_cpi.drop(['0,1], axis=1)
df_us_cpi
# Out:
# 0   index  10  Year      Jan      Feb      Mar      Apr      May      Jun  \
# 0       1  11  1947    21.48    21.62    22.00    22.00    21.95    22.08
# 1       2  12  1948    23.68    23.67    23.50    23.82    24.01    24.15
# 2       3  13  1949    24.01    23.91    23.91    23.92    23.91    23.92
# 3       4  14  1950    23.51    23.61    23.64    23.65    23.77    23.88
# 4       5  15  1951    25.38    25.83    25.88    25.92    25.99    25.93
# 5       6  16  1952    26.45    26.41    26.39    26.46    26.47    26.53
# 6       7  17  1953    26.64    26.59    26.63    26.69    26.70    26.77
# 7       8  18  1954    26.94    26.99    26.93    26.86    26.93    26.94
# 8       9  19  1955    26.77    26.82    26.79    26.79    26.77    26.71
# 9      10  20  1956    26.83    26.86    26.89    26.93    27.03    27.15
# 10     11  21  1957    27.67    27.80    27.86    27.93    28.00    28.11
# 11     12  22  1958    28.64    28.70    28.87    28.94    28.94    28.91
# 12     13  23  1959    29.01    29.00    28.97    28.98    29.04    29.11
# 13     14  24  1960    29.37    29.41    29.41    29.54    29.57    29.61
# 14     15  25  1961    29.84    29.84    29.84    29.81    29.84    29.84
# 15     16  26  1962    30.04    30.11    30.17    30.21    30.24    30.21
# 16     17  27  1963    30.44    30.48    30.51    30.48    30.51    30.61
# 17     18  28  1964    30.94    30.91    30.94    30.95    30.98    31.01
# 18     19  29  1965    31.28    31.28    31.31    31.38    31.48    31.61
# 19     20  30  1966    31.88    32.08    32.18    32.28    32.35    32.38
# 54   177.40   177.40   178.10   177.60   177.50   177.40   NaN   NaN
# 55    180.0    180.5    180.8    181.2    181.5    181.8   NaN   NaN
# 56    183.7    184.5    185.1    184.9    185.0    185.5   NaN   NaN
# 57    189.1    189.2    189.8    190.8    191.7    191.7   NaN   NaN
# 58    194.9    196.1    198.8    199.1    198.1    198.1   NaN   NaN
# 59    202.9    203.8    202.8    201.9    202.0    203.1   NaN   NaN
# 60  207.603  207.667  208.547  209.190  210.834  211.445   NaN   NaN
# 61  219.016  218.690  218.877  216.995  213.153  211.398   NaN   NaN
# 62  214.726  215.445  215.861  216.509  217.234  217.347   NaN   NaN
# 63  217.605  217.923  218.275  219.035  219.590  220.472   NaN   NaN
# 64  225.395  226.106  226.597  226.750  227.169  227.223   NaN   NaN
# 65  228.590  229.918  231.015  231.638  231.249  231.221   NaN   NaN
# 66  232.900  233.456  233.544  233.669  234.100  234.719   NaN   NaN
# 67  237.498  237.460  237.477  237.430  236.983  236.252   NaN   NaN
# 68  238.053  238.028  237.506  237.781  238.016  237.817   NaN   NaN
# 69  240.150  240.602  241.051  241.691  242.029  242.772   NaN   NaN
# 70  244.390  245.297  246.418  246.587  247.332  247.901   NaN   NaN
# 71  251.597  251.879  252.010  252.794  252.760  252.723   NaN   NaN
# 72      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN
#
# [73 rows x 17 columns]

# %%
df_us_cpi = df_us_cpi.drop(['index', 10, 'HALF1','HALF2'], axis=1)

# %%
list_name = df_us_cpi.columns
list_name
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'total'],
#       dtype='object', name=0)

# %%
df_us_cpi[list_name].astype(float)
df_us_cpi['Year']=df_us_cpi['Year'].astype(int)

# %%
list_name
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'total'],
#       dtype='object', name=0)

# %%
list_name=list_name[1:]

# %%
list_name
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec', 'total'],
#       dtype='object', name=0)

# %%
df_us_cpi['total']=df_us_cpi.loc[:,list_name].sum(axis=1)

# %%
df_us_cpi
# Out:
# 0   Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   1947    21.48    21.62    22.00    22.00    21.95    22.08    22.23
# 1   1948    23.68    23.67    23.50    23.82    24.01    24.15    24.40
# 2   1949    24.01    23.91    23.91    23.92    23.91    23.92    23.70
# 3   1950    23.51    23.61    23.64    23.65    23.77    23.88    24.07
# 4   1951    25.38    25.83    25.88    25.92    25.99    25.93    25.91
# 5   1952    26.45    26.41    26.39    26.46    26.47    26.53    26.68
# 6   1953    26.64    26.59    26.63    26.69    26.70    26.77    26.79
# 7   1954    26.94    26.99    26.93    26.86    26.93    26.94    26.86
# 8   1955    26.77    26.82    26.79    26.79    26.77    26.71    26.76
# 9   1956    26.83    26.86    26.89    26.93    27.03    27.15    27.29
# 10  1957    27.67    27.80    27.86    27.93    28.00    28.11    28.19
# 11  1958    28.64    28.70    28.87    28.94    28.94    28.91    28.89
# 12  1959    29.01    29.00    28.97    28.98    29.04    29.11    29.15
# 58    196.1    198.8    199.1    198.1    198.1    0.0
# 59    203.8    202.8    201.9    202.0    203.1    0.0
# 60  207.667  208.547  209.190  210.834  211.445    0.0
# 61  218.690  218.877  216.995  213.153  211.398    0.0
# 62  215.445  215.861  216.509  217.234  217.347    0.0
# 63  217.923  218.275  219.035  219.590  220.472    0.0
# 64  226.106  226.597  226.750  227.169  227.223    0.0
# 65  229.918  231.015  231.638  231.249  231.221    0.0
# 66  233.456  233.544  233.669  234.100  234.719    0.0
# 67  237.460  237.477  237.430  236.983  236.252    0.0
# 68  238.028  237.506  237.781  238.016  237.817    0.0
# 69  240.602  241.051  241.691  242.029  242.772    0.0
# 70  245.297  246.418  246.587  247.332  247.901    0.0
# 71  251.879  252.010  252.794  252.760  252.723    0.0
# 72      NaN      NaN      NaN      NaN      NaN    0.0
#
# [73 rows x 14 columns]

# %%
df_us_import = df_us_ie_2k5.loc[df_us_ie_2k5[4].isna()]
df_us_export = df_us_ie_2k5.loc[df_us_ie_2k5[5].isna()]
df_us_both = df_us_ie_2k5.loc[~df_us_ie_2k5[4].isna() & ~df_us_ie_2k5[5].isna()]

# %%
gb = df_us_ie.groupby([0,1,2]).sum()
df_by = pd.DataFrame(gb)

# df_us_ie=df_us_ie.drop([3], axis=1)
df_by.columns
# Out:
# Int64Index([3, 4, 5], dtype='int64')

# %%
df_by.head()
df_us_ir.head()
# Out:
#          DATE VALUE
# 0  2001-07-31  3.67
# 1  2001-08-01  3.65
# 2  2001-08-02  3.65
# 3  2001-08-03  3.63
# 4  2001-08-06  3.62

# %%
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir.info()
df_us_ir.head()
ser = df_us_ir.set_index('year')['VALUE']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4553 entries, 0 to 4552
# Data columns (total 3 columns):
# DATE     4553 non-null object
# VALUE    4553 non-null object
# year     4553 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 106.8+ KB

# %%
df_us_import['ir']=ser
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b00fef16e9cb> in <module>
# ----> 1 df_us_import['ir']=ser
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3605
#    3606         if isinstance(value, Series):
# -> 3607             value = reindexer(value)
#    3608
#    3609         elif isinstance(value, DataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3597                     # duplicate axis
#    3598                     if not value.index.is_unique:
# -> 3599                         raise e
#    3600
#    3601                     # other
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3592                 # GH 4107
#    3593                 try:
# -> 3594                     value = value.reindex(self.index)._values
#    3595                 except Exception as e:
#    3596
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3736     @Appender(generic.NDFrame.reindex.__doc__)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#    3740     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4372             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    4373                                              fill_value=fill_value,
# -> 4374                                              copy=copy, allow_dups=False)
#    4375
#    4376         return obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3085         # trying to reindex on an axis with duplicates
#    3086         if not self.is_unique and len(indexer):
# -> 3087             raise ValueError("cannot reindex from a duplicate axis")
#    3088
#    3089     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
dir
# Out:
# <function dir>

# %%
df_by.head()
df_us_yearly = df_by.drop(3, axis=1)
df_us_yearly[]
# Out:
# 0     1    2
# 1998  abw  usa    4.347535e+08
#       afg  usa    1.171142e+07
#       ago  usa    2.130024e+09
#       aia  usa    4.168978e+05
#       alb  usa    1.520175e+07
#       and  usa    1.112868e+05
#       ant  usa    3.956132e+08
#       are  usa    5.366266e+08
#       arg  usa    2.279315e+09
#       arm  usa    1.119336e+07
#       atf  usa    8.691959e+05
#       atg  usa    8.067535e+05
#       aus  usa    5.039213e+09
#       aut  usa    2.464370e+09
#       aze  usa    2.093998e+06
#       bdi  usa    7.473559e+06
#       ben  usa    3.132474e+06
#       bfa  usa    8.546008e+04
#       bgd  usa    1.925556e+09
#       bgr  usa    1.863924e+08
#       bhr  usa    1.519695e+08
#       bhs  usa    2.385032e+08
#       bih  usa    4.577565e+06
#       blr  usa    1.305910e+08
#       blx  usa    6.692466e+09
#       blz  usa    7.940652e+07
#       bmu  usa    2.147413e+06
#       bol  usa    2.523581e+08
#       bra  usa    1.037290e+10
#       brb  usa    1.248111e+07
#                       ...
# 2017  usa  tza    1.966404e+08
#            uga    1.145996e+08
#            ukr    2.329893e+09
#            ury    9.564344e+08
#            uzb    4.332531e+07
#            vct    1.251135e+08
#            ven    3.464164e+09
#            vgb    2.038972e+08
#            vnm    4.982565e+09
#            vut    3.086058e+06
#            wlf    1.370270e+05
#            wsm    4.673340e+07
#            xxb    1.117214e+10
#            yem    1.921782e+08
#            zaf    5.449711e+09
#            zmb    1.088141e+08
#            zwe    2.541907e+07
#       uzb  usa    6.388175e+06
#       vct  usa    5.224496e+06
#       ven  usa    1.164483e+10
#       vgb  usa    3.117231e+06
#       vnm  usa    4.611073e+10
#       vut  usa    5.354408e+06
#       wlf  usa    2.259400e+04
#       wsm  usa    5.358475e+06
#       xxb  usa    3.730489e+10
#       yem  usa    9.432389e+06
#       zaf  usa    8.023121e+09
#       zmb  usa    2.517072e+07
#       zwe  usa    4.523361e+07
# Name: 4, Length: 7426, dtype: float64

# %%
df_us_ie[df_us_ie[3]==20130]
# Out:
#              0    1    2      3             4             5
# 0         1998  ago  usa  20130           NaN  1.600000e+04
# 1032      1998  civ  usa  20130           NaN  3.206100e+04
# 2475      1998  dza  usa  20130           NaN  1.064000e+03
# 4076      1998  egy  usa  20130           NaN  1.398800e+05
# 12342076  2017  bra  usa  20130  9.220448e+05  2.803970e+05
# 12345749  2017  chl  usa  20130  3.410565e+05  4.151995e+07
# 12349346  2017  col  usa  20130           NaN  2.790701e+06
# 12356387  2017  guy  usa  20130           NaN  3.641610e+03
# 12358925  2017  per  usa  20130           NaN  4.351180e+06
# 12362417  2017  pry  usa  20130           NaN  7.560000e+03
# 12364386  2017  sur  usa  20130           NaN  2.689800e+04
# 12366481  2017  ury  usa  20130  2.663538e+07           NaN
#
# [2732 rows x 6 columns]

# %%
df_us_import = df_us_ie.loc[df_us_ie[4].isna()]
df_us_export = df_us_ie.loc[df_us_ie[5].isna()]
# df_us_import = df_us_import.drop([4], axis=1)
# df_us_export = df_us_export.drop([5], axis=1)

# %%
df_us_import = df_us_ie.loc[df_us_ie[4].isna()]
df_us_export = df_us_ie.loc[df_us_ie[5].isna()]
df_us_both = df_us_ie.loc[~df_us_ie[4].isna() & ~df_us_ie[5].isna()]

# %%
df_us_import.count()
# Out:
# 0    4103939
# 1    4103939
# 2    4103939
# 3    4103939
# 4          0
# 5    4103939
# dtype: int64

# %%
df_us_export.count()
# Out:
# 0    4017241
# 1    4017241
# 2    4017241
# 3    4017241
# 4    4017241
# 5          0
# dtype: int64

# %%
df_us_both.count()
# Out:
# 0    4249614
# 1    4249614
# 2    4249614
# 3    4249614
# 4    4249614
# 5    4249614
# dtype: int64

# %%
new_df=df_us_import.merge(df_us_export, on=[0], how='inner' )
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-73-6c7f17e529de> in <module>
# ----> 1 new_df=df_us_import.merge(df_us_export, on=[0], how='inner' )
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      46                          copy=copy, indicator=indicator,
#      47                          validate=validate)
# ---> 48     return op.get_result()
#      49
#      50
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     544                 self.left, self.right)
#     545
# --> 546         join_index, left_indexer, right_indexer = self._get_join_info()
#     547
#     548         ldata, rdata = self.left._data, self.right._data
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     754         else:
#     755             (left_indexer,
# --> 756              right_indexer) = self._get_join_indexers()
#     757
#     758             if self.right_index:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     733                                   self.right_join_keys,
#     734                                   sort=self.sort,
# --> 735                                   how=self.how)
#     736
#     737     def _get_join_info(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1144     join_func = _join_functions[how]
#    1145
# -> 1146     return join_func(lkey, rkey, count, **kwargs)
#    1147
#    1148
#
# pandas/_libs/join.pyx in pandas._libs.join.inner_join()
#
# MemoryError:

# %%
# new_df=df_us_import.join(df_us_export, on=[0,1,2,3])
new_df=pd.concat([df_us_import, df_us_export])
new_df

# %%
gb = df_us_ie.groupby([0,1,2]).sum()

# %%
df_us_ie_sum = pd.DataFrame(new_df_us_ie)
df_us_ie_sum.drop([3], axis=1)
# Out:
#                          4             5
# 0    1   2
# 1998 abw usa  4.347535e+08  2.448266e+08
#      afg usa  1.171142e+07  4.037272e+06
#      ago usa  2.130024e+09  1.686776e+08
#      aia usa  4.168978e+05  9.580838e+06
#      alb usa  1.520175e+07  1.844270e+07
#      and usa  1.112868e+05  3.270806e+07
#      ant usa  3.956132e+08  7.346264e+08
#      are usa  5.366266e+08  1.599038e+09
#      arg usa  2.279315e+09  6.212280e+09
#      arm usa  1.119336e+07  3.044603e+07
#      atf usa  8.691959e+05  5.484640e+05
#      atg usa  8.067535e+05  5.292213e+07
#      aus usa  5.039213e+09  9.778649e+09
#      aut usa  2.464370e+09  3.082170e+09
#      aze usa  2.093998e+06  9.132723e+07
#      bdi usa  7.473559e+06  3.583323e+06
#      ben usa  3.132474e+06  5.997634e+07
#      bfa usa  8.546008e+04  1.296847e+07
#      bgd usa  1.925556e+09  2.417591e+08
#      bgr usa  1.863924e+08  1.948520e+08
#      bhr usa  1.519695e+08  1.451327e+08
#      bhs usa  2.385032e+08  9.996376e+08
#      bih usa  4.577565e+06  3.056716e+07
#      blr usa  1.305910e+08  1.192061e+08
#      blx usa  6.692466e+09  1.173211e+10
#      blz usa  7.940652e+07  1.563471e+08
#      bmu usa  2.147413e+06  2.672270e+08
#      bol usa  2.523581e+08  5.403535e+08
#      bra usa  1.037290e+10  1.458697e+10
#      brb usa  1.248111e+07  1.727801e+08
# ...                    ...           ...
# 2017 usa tza  1.966404e+08  1.274681e+08
#          uga  1.145996e+08  6.907687e+07
#          ukr  2.329893e+09  9.141624e+08
#          ury  9.564344e+08  4.728028e+08
#          uzb  4.332531e+07  6.388175e+06
#          vct  1.251135e+08  5.224496e+06
#          ven  3.464164e+09  1.164483e+10
#          vgb  2.038972e+08  3.117231e+06
#          vnm  4.982565e+09  4.611073e+10
#          vut  3.086058e+06  5.354408e+06
#          wlf  1.370270e+05  2.259400e+04
#          wsm  4.673340e+07  5.358475e+06
#          xxb  1.117214e+10  3.730489e+10
#          yem  1.921782e+08  9.432389e+06
#          zaf  5.449711e+09  8.023121e+09
#          zmb  1.088141e+08  2.517072e+07
#          zwe  2.541907e+07  4.523361e+07
#      uzb usa  6.388175e+06  4.332531e+07
#      vct usa  5.224496e+06  1.251135e+08
#      ven usa  1.164483e+10  3.464164e+09
#      vgb usa  3.117231e+06  2.038972e+08
#      vnm usa  4.611073e+10  4.982565e+09
#      vut usa  5.354408e+06  3.086058e+06
#      wlf usa  2.259400e+04  1.370270e+05
#      wsm usa  5.358475e+06  4.673340e+07
#      xxb usa  3.730489e+10  1.117214e+10
#      yem usa  9.432389e+06  1.921782e+08
#      zaf usa  8.023121e+09  5.449711e+09
#      zmb usa  2.517072e+07  1.088141e+08
#      zwe usa  4.523361e+07  2.541907e+07
#
# [7426 rows x 2 columns]

# %%
df_us_ie_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7426 entries, (1998, abw, usa) to (2017, zwe, usa)
# Data columns (total 3 columns):
# 3    7426 non-null int64
# 4    7426 non-null float64
# 5    7426 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 214.0+ KB

# %%
df_us_ie.
