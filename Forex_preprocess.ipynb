# %%
import pandas as pd
import numpy as np

# %%
file_path = '../CapStone/ForeignEx/data/'
file_path_us = file_path + 'US'
file_path_eu = file_path + 'EU'
df_us_cpi = pd.read_csv('../CapStone/ForeignEx/data/US/US_CPI_SeriesReport_monthly_2019_1947.csv', sep='\t')
df_us_ir = pd.read_csv('../CapStone/ForeignEx/data/US/US_Month_Treasury_Constant_Maturity_Rate.csv')
df_us_ie = pd.read_csv('../CapStone/ForeignEx/data/US/usa_iexport.tsv', sep='\t', header=None)

# %%
df_us_ie_2k5 = df_us_ie[ df_us_ie[0] >= 2005]

# %%
df_us_ie_2k5.head()
df_us_jpn_ie = df_us_ie[(df_us_ie[1] == 'jpn') | (df_us_ie[2] == 'jpn')]
# df_us_jpn_ie.head()

# %%
df_us_jpn_ie[4] = df_us_jpn_ie[4].fillna(value=0)
df_us_jpn_ie.head()
df_us_jpn_ie[5] = df_us_jpn_ie[5].fillna(value=0)
df_us_jpn_ie.head()
# Out:
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           0    1    2      3           4            5
# 51079  1998  jpn  usa  10111   584310.00  23397947.55
# ...

# %%
gby = df_us_jpn_ie.groupby([0,1,2]).sum().reset_index()

# %%
df_us_jpn_his = gby[::2].reset_index()

# %%
#### df_us_ir
# df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))

df_us_ir
# Out:
#             DATE USintRate  year
# 0     2001/07/31      3.67  2001
# 1     2001/08/01      3.65  2001
# 2     2001/08/02      3.65  2001
# 3     2001/08/03      3.63  2001
# 4     2001/08/06      3.62  2001
# 5     2001/08/07      3.63  2001
# 6     2001/08/08      3.61  2001
# 7     2001/08/09      3.61  2001
# 8     2001/08/10      3.58  2001
# 9     2001/08/13      3.57  2001
# 10    2001/08/14      3.54  2001
# 11    2001/08/15      3.52  2001
# 12    2001/08/16      3.48  2001
# 13    2001/08/17      3.46  2001
# 14    2001/08/20      3.48  2001
# 15    2001/08/21      3.46  2001
# 16    2001/08/22      3.46  2001
# 17    2001/08/23      3.49  2001
# 18    2001/08/24      3.49  2001
# 19    2001/08/27      3.52  2001
# 20    2001/08/28      3.53  2001
# 21    2001/08/29      3.48  2001
# 22    2001/08/30      3.41  2001
# 23    2001/08/31       3.4  2001
# 24    2001/09/03         .  2001
# 25    2001/09/04      3.43  2001
# 26    2001/09/05      3.49  2001
# ...

# %%
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir.info()
df_us_ir.head()
#ser = df_us_ir.set_index('year')['VALUE']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4553 entries, 0 to 4552
# Data columns (total 3 columns):
# DATE         4553 non-null object
# USintRate    4553 non-null object
# year         4553 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 106.8+ KB
#          DATE USintRate  year
# 0  2001/07/31      3.67  2001
# 1  2001/08/01      3.65  2001
# 2  2001/08/02      3.65  2001
# 3  2001/08/03      3.63  2001
# 4  2001/08/06      3.62  2001

# %%
# df_us_ir['VALUE'].apply(lambda x:float(x))
# df_us_ir.VALUE = df_us_ir.VALUE.astype(float)
# df_us_ir.VALUE.describe()
# df_us_ir['VALUE'] = df_us_ir['VALUE'].astype(float)
# df_us_ir = pd.read_csv('../CapStone/ForeignEx/data/US/US_Month_Treasury_Constant_Maturity_Rate.csv')

df_us_ir = df_us_ir[~(df_us_ir['USintRate'] == '.')]
df_us_ir['USintRate'] = df_us_ir['USintRate'].astype(float)

df_us_ir.groupby('DATE').mean()
df_us_ir['YEAR']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir_his = df_us_ir.groupby('YEAR').mean()
# Out:
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\OrsonKong\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_us_cpi = df_us_cpi[10:].reset_index()

# %%
df_us_cpi.columns = df_us_cpi.iloc[0]
df_us_cpi = df_us_cpi.drop(0).reset_index()

# %%
# df_us_cpi.drop(['0,1], axis=1)
df_us_cpi
# Out:
# 0   index  10  Year      Jan      Feb      Mar      Apr      May      Jun  \
# 0       1  11  1947    21.48    21.62       22       22    21.95    22.08
# 1       2  12  1948    23.68    23.67     23.5    23.82    24.01    24.15
# 2       3  13  1949    24.01    23.91    23.91    23.92    23.91    23.92
# 3       4  14  1950    23.51    23.61    23.64    23.65    23.77    23.88
# 4       5  15  1951    25.38    25.83    25.88    25.92    25.99    25.93
# 5       6  16  1952    26.45    26.41    26.39    26.46    26.47    26.53
# 6       7  17  1953    26.64    26.59    26.63    26.69     26.7    26.77
# 7       8  18  1954    26.94    26.99    26.93    26.86    26.93    26.94
# 8       9  19  1955    26.77    26.82    26.79    26.79    26.77    26.71
# 9      10  20  1956    26.83    26.86    26.89    26.93    27.03    27.15
# 10     11  21  1957    27.67     27.8    27.86    27.93       28    28.11
# 11     12  22  1958    28.64     28.7    28.87    28.94    28.94    28.91
# ...

# %%
df_us_cpi = df_us_cpi.drop(['index', 10, 'HALF1','HALF2'], axis=1)

# %%
list_name = df_us_cpi.columns
list_name
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'],
#       dtype='object', name=0)

# %%
df_us_cpi = df_us_cpi[list_name].astype(float)

# %%
df_us_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 13 columns):
# Year    73 non-null float64
# Jan     73 non-null float64
# Feb     73 non-null float64
# Mar     72 non-null float64
# Apr     72 non-null float64
# May     72 non-null float64
# Jun     72 non-null float64
# Jul     72 non-null float64
# Aug     72 non-null float64
# Sep     72 non-null float64
# Oct     72 non-null float64
# Nov     72 non-null float64
# Dec     72 non-null float64
# dtypes: float64(13)
# memory usage: 7.5 KB

# %%
# df_us_cpi[list_name].astype(float)
df_us_cpi['Year']=df_us_cpi['Year'].astype(int)

# %%
df_us_cpi
list_name
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'],
#       dtype='object', name=0)

# %%
list_name=list_name[1:]

# %%
list_name
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object', name=0)

# %%
# df_us_cpi.loc[:,list_name].sum(axis=0)
# df_us_cpi['total_n']=df_us_cpi.loc[:,list_name].sum(axis=1)
# df_us_cpi['total_n']=df_us_cpi.loc[:,list_name].mean(axis=1)

# %%
df_us_cpi['USCPI']=df_us_cpi.loc[:,list_name].mean(axis=1)

# %%
df_us_cpi_his = df_us_cpi[['Year','USCPI']]

# %%
df_us_ie_his = pd.read_csv('../CapStone/ForeignEx/data/US_EU_year.csv')
df_oil_his = pd.read_csv('../CapStone/ForeignEx/data/oil_price_year.csv')
df_us_gdp_his = pd.read_csv('../CapStone/ForeignEx/data/US/US_GDP.csv')

# %%
master_his= df_us_cpi_his.join(df_us_gdp_his)
#df_us_gdp_his.merge(df_us_cpi_his)

# %%
master_his = master_his.set_index('Year').join(df_us_ie_his.set_index('year'))
#df.join(other.set_index('key'), on='key')
 # df.set_index('key').join(other.set_index('key'))

# %%
master_his=master_his.join(df_oil_his.set_index('Date'))

# %%
master_his = master_his.join(df_us_ir_his)

# %%
df_eu_cpi = pd.read_csv('../CapStone/ForeignEx/data/EU/EU_CPI_year.csv')
df_eu_gdp = pd.read_csv('../CapStone/ForeignEx/data/EU/EU_GDP_year.csv')

# %%
df_ex_rate= pd.read_csv('./data/US/Annual.csv')

# %%
df_eu_cpi.columns
df_eu_gdp.columns
df_ex_rate.columns
# Out:
# Index(['YEAR', 'EXRATEUSEU'], dtype='object')

# %%
master_his = master_his.join(df_eu_cpi.set_index('YEAR'))
master_his = master_his.join(df_eu_gdp.set_index('DATE'))

# %%
master_his=master_his.join(df_ex_rate.set_index('YEAR'))

# %%
master_his.sort_values('Year',ascending=False).to_csv('./data/master_test.csv')

# %%
master_his
# Out:
#            USCPI    YEAR     GDPUSD          IYR          EYR   USDBarrel  \
# Year
# 1947   22.331667  1947.0    259.745          NaN          NaN         NaN
# 1948   24.045000  1948.0    280.366          NaN          NaN         NaN
# 1949   23.809167  1949.0    270.627          NaN          NaN         NaN
# 1950   24.062500  1950.0    319.945          NaN          NaN         NaN
# 1951   25.973333  1951.0    356.178          NaN          NaN         NaN
# 1952   26.566667  1952.0    380.812          NaN          NaN         NaN
# 1953   26.768333  1953.0    385.970          NaN          NaN         NaN
# 1954   26.865000  1954.0    399.734          NaN          NaN         NaN
# 1955   26.795833  1955.0    437.092          NaN          NaN         NaN
# 1956   27.190833  1956.0    460.463          NaN          NaN         NaN
# 1957   28.113333  1957.0    474.864          NaN          NaN         NaN
# 1958   28.880833  1958.0    499.555          NaN          NaN         NaN
# ...

# %%
import pickle

# path = './'
with open ('forex_pic', 'rb') as file:
    pickle.dump(master_his, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-610-21e89e78249c> in <module>
#       2
#       3 # path = './'
# ----> 4 with open ('forex_pic', 'rb') as file:
#       5     pickle.dump(master_his, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'forex_pic'

# %%
df_us_import = df_us_ie_2k5.loc[df_us_ie_2k5[4].isna()]
df_us_export = df_us_ie_2k5.loc[df_us_ie_2k5[5].isna()]
df_us_both = df_us_ie_2k5.loc[~df_us_ie_2k5[4].isna() & ~df_us_ie_2k5[5].isna()]

# %%
gb = df_us_ie.groupby([0,1,2]).sum()
df_by = pd.DataFrame(gb)

# df_us_ie=df_us_ie.drop([3], axis=1)
df_by.columns
# Out:
# Int64Index([3, 4, 5], dtype='int64')

# %%
df_by.head()
df_us_ir.head()
# Out:
#          DATE VALUE
# 0  2001-07-31  3.67
# 1  2001-08-01  3.65
# 2  2001-08-02  3.65
# 3  2001-08-03  3.63
# 4  2001-08-06  3.62

# %%
df_us_ir['year']=df_us_ir['DATE'].apply(lambda x: int(x[:4]))
df_us_ir.info()
df_us_ir.head()
ser = df_us_ir.set_index('year')['VALUE']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4553 entries, 0 to 4552
# Data columns (total 3 columns):
# DATE     4553 non-null object
# VALUE    4553 non-null object
# year     4553 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 106.8+ KB

# %%
dir
# Out:
# <function dir>

# %%
df_by.head()
df_us_yearly = df_by.drop(3, axis=1)
df_us_yearly[]
# Out:
# 0     1    2
# 1998  abw  usa    4.347535e+08
#       afg  usa    1.171142e+07
#       ago  usa    2.130024e+09
#       aia  usa    4.168978e+05
#       alb  usa    1.520175e+07
#       and  usa    1.112868e+05
#       ant  usa    3.956132e+08
#       are  usa    5.366266e+08
#       arg  usa    2.279315e+09
#       arm  usa    1.119336e+07
#       atf  usa    8.691959e+05
#       atg  usa    8.067535e+05
#       aus  usa    5.039213e+09
#       aut  usa    2.464370e+09
#       aze  usa    2.093998e+06
#       bdi  usa    7.473559e+06
#       ben  usa    3.132474e+06
#       bfa  usa    8.546008e+04
#       bgd  usa    1.925556e+09
#       bgr  usa    1.863924e+08
#       bhr  usa    1.519695e+08
#       bhs  usa    2.385032e+08
#       bih  usa    4.577565e+06
#       blr  usa    1.305910e+08
#       blx  usa    6.692466e+09
#       blz  usa    7.940652e+07
#       bmu  usa    2.147413e+06
#       bol  usa    2.523581e+08
#       bra  usa    1.037290e+10
# ...

# %%
df_us_ie[df_us_ie[3]==20130]
# Out:
#              0    1    2      3             4             5
# 0         1998  ago  usa  20130           NaN  1.600000e+04
# 1032      1998  civ  usa  20130           NaN  3.206100e+04
# 2475      1998  dza  usa  20130           NaN  1.064000e+03
# 4076      1998  egy  usa  20130           NaN  1.398800e+05
# 7877      1998  gin  usa  20130           NaN  1.606176e+04
# 16296     1998  syc  usa  20130           NaN  1.201140e+03
# 23718     1998  are  usa  20130           NaN  9.020300e+04
# 27907     1998  chn  usa  20130           NaN  1.659040e+05
# 34766     1998  hkg  usa  20130           NaN  3.385472e+06
# 38545     1998  idn  usa  20130           NaN  1.425110e+03
# 42349     1998  ind  usa  20130  4.359400e+04           NaN
# 46593     1998  isr  usa  20130           NaN  1.475910e+05
# 49479     1998  jor  usa  20130           NaN  1.547700e+04
# 51094     1998  jpn  usa  20130  9.541405e+05  7.759332e+08
# 57430     1998  kor  usa  20130           NaN  8.935418e+05
# ...

# %%
df_us_import = df_us_ie.loc[df_us_ie[4].isna()]
df_us_export = df_us_ie.loc[df_us_ie[5].isna()]
# df_us_import = df_us_import.drop([4], axis=1)
# df_us_export = df_us_export.drop([5], axis=1)

# %%
df_us_import = df_us_ie.loc[df_us_ie[4].isna()]
df_us_export = df_us_ie.loc[df_us_ie[5].isna()]
df_us_both = df_us_ie.loc[~df_us_ie[4].isna() & ~df_us_ie[5].isna()]

# %%
df_us_import.count()
# Out:
# 0    4103939
# 1    4103939
# 2    4103939
# 3    4103939
# 4          0
# 5    4103939
# dtype: int64

# %%
df_us_export.count()
# Out:
# 0    4017241
# 1    4017241
# 2    4017241
# 3    4017241
# 4    4017241
# 5          0
# dtype: int64

# %%
df_us_both.count()
# Out:
# 0    4249614
# 1    4249614
# 2    4249614
# 3    4249614
# 4    4249614
# 5    4249614
# dtype: int64

# %%
# new_df=df_us_import.join(df_us_export, on=[0,1,2,3])
new_df=pd.concat([df_us_import, df_us_export])
new_df

# %%
gb = df_us_ie.groupby([0,1,2]).sum()

# %%
df_us_ie_sum = pd.DataFrame(new_df_us_ie)
df_us_ie_sum.drop([3], axis=1)
# Out:
#                          4             5
# 0    1   2
# 1998 abw usa  4.347535e+08  2.448266e+08
#      afg usa  1.171142e+07  4.037272e+06
#      ago usa  2.130024e+09  1.686776e+08
#      aia usa  4.168978e+05  9.580838e+06
#      alb usa  1.520175e+07  1.844270e+07
#      and usa  1.112868e+05  3.270806e+07
#      ant usa  3.956132e+08  7.346264e+08
#      are usa  5.366266e+08  1.599038e+09
#      arg usa  2.279315e+09  6.212280e+09
#      arm usa  1.119336e+07  3.044603e+07
#      atf usa  8.691959e+05  5.484640e+05
#      atg usa  8.067535e+05  5.292213e+07
#      aus usa  5.039213e+09  9.778649e+09
#      aut usa  2.464370e+09  3.082170e+09
#      aze usa  2.093998e+06  9.132723e+07
#      bdi usa  7.473559e+06  3.583323e+06
#      ben usa  3.132474e+06  5.997634e+07
#      bfa usa  8.546008e+04  1.296847e+07
#      bgd usa  1.925556e+09  2.417591e+08
#      bgr usa  1.863924e+08  1.948520e+08
#      bhr usa  1.519695e+08  1.451327e+08
# ...

# %%
df_us_ie_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7426 entries, (1998, abw, usa) to (2017, zwe, usa)
# Data columns (total 3 columns):
# 3    7426 non-null int64
# 4    7426 non-null float64
# 5    7426 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 214.0+ KB

# %%
df_us_ie.
